# %%
import numpy as np
import pandas as pd

# %%
pd1 = pd.read_csv('olympics.csv', skiprows=3)

# %%
pd1.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
pd1.columns
# Out:
# Index(['City', 'Edition', 'Sport', 'Discipline', 'Athlete', 'NOC', 'Gender',
#        'Event', 'Event_gender', 'Medal'],
#       dtype='object')

# %%
type(pd1)
# Out:
# pandas.core.frame.DataFrame

# %%
pd1.Athlete[:5]
# Out:
# 0         HAJOS, Alfred
# 1      HERSCHMANN, Otto
# 2     DRIVAS, Dimitrios
# 3    MALOKINIS, Ioannis
# 4    CHASAPIS, Spiridon
# Name: Athlete, dtype: object

# %%
type(pd1.Athlete)
# Out:
# pandas.core.series.Series

# %%
pd1['Athlete'].head()
# Out:
# 0         HAJOS, Alfred
# 1      HERSCHMANN, Otto
# 2     DRIVAS, Dimitrios
# 3    MALOKINIS, Ioannis
# 4    CHASAPIS, Spiridon
# Name: Athlete, dtype: object

# %%
pd1[['Athlete', 'Gender']].head()
# Out:
#               Athlete Gender
# 0       HAJOS, Alfred    Men
# 1    HERSCHMANN, Otto    Men
# 2   DRIVAS, Dimitrios    Men
# 3  MALOKINIS, Ioannis    Men
# 4  CHASAPIS, Spiridon    Men

# %%
pd1.shape
# Out:
# (29216, 10)

# %%
len(pd1.Name)
# Out:
# 271116

# %%
pd1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
# ID        271116 non-null int64
# Name      271116 non-null object
# Sex       271116 non-null object
# Age       261642 non-null float64
# Height    210945 non-null float64
# Weight    208241 non-null float64
# Team      271116 non-null object
# NOC       271116 non-null object
# Games     271116 non-null object
# Year      271116 non-null int64
# Season    271116 non-null object
# City      271116 non-null object
# Sport     271116 non-null object
# Event     271116 non-null object
# Medal     39783 non-null object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
pd1 = pd.read_csv("olympics.csv")

# %%
pd1.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
pd1.tail()
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender       Event Event_gender   Medal
# 29211  GER    Men   84 - 96kg            M  Silver
# 29212  LTU    Men  96 - 120kg            M  Bronze
# 29213  ARM    Men  96 - 120kg            M  Bronze
# 29214  CUB    Men  96 - 120kg            M    Gold
# 29215  RUS    Men  96 - 120kg            M  Silver

# %%
pd1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
# City            29216 non-null object
# Edition         29216 non-null int64
# Sport           29216 non-null object
# Discipline      29216 non-null object
# Athlete         29216 non-null object
# NOC             29216 non-null object
# Gender          29216 non-null object
# Event           29216 non-null object
# Event_gender    29216 non-null object
# Medal           29216 non-null object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %%
pd1['Edition'].value_counts()
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
pd1.Gender.value_counts()
# Out:
# Men      21721
# Women     7495
# Name: Gender, dtype: int64

# %%
pd1['Athlete'].sort_values()
# Out:
# 651                 AABYE, Edgar
# 2849       AALTONEN, Arvo Ossian
# 2852       AALTONEN, Arvo Ossian
# 7716    AALTONEN, Paavo Johannes
# 7730    AALTONEN, Paavo Johannes
#                   ...
# 603                   ÖSTMO, Ole
# 608                   ÖSTMO, Ole
# 621                   ÖSTMO, Ole
# 596                   ÖSTMO, Ole
# 8051           ÖSTRAND, Per-Olof
# Name: Athlete, Length: 29216, dtype: object

# %%
pd1.Athlete.sort_values(ascending=False)
# Out:
# 8051           ÖSTRAND, Per-Olof
# 596                   ÖSTMO, Ole
# 621                   ÖSTMO, Ole
# 608                   ÖSTMO, Ole
# 603                   ÖSTMO, Ole
#                   ...
# 7730    AALTONEN, Paavo Johannes
# 7716    AALTONEN, Paavo Johannes
# 2852       AALTONEN, Arvo Ossian
# 2849       AALTONEN, Arvo Ossian
# 651                 AABYE, Edgar
# Name: Athlete, Length: 29216, dtype: object

# %%
pd1.sort_values(by=['Edition', 'Athlete'])
#First Sorts By Edition and inside Each Edition Sorts by Athlete
# Out:
#           City  Edition       Sport    Discipline  \
# 7       Athens     1896    Aquatics      Swimming
# 82      Athens     1896  Gymnastics   Artistic G.
# 110     Athens     1896  Gymnastics   Artistic G.
# 111     Athens     1896  Gymnastics   Artistic G.
# 48      Athens     1896     Cycling  Cycling Road
# ...        ...      ...         ...           ...
# 28095  Beijing     2008  Equestrian      Dressage
# 28819  Beijing     2008     Sailing       Sailing
# 28977  Beijing     2008   Taekwondo     Taekwondo
# 28387  Beijing     2008  Gymnastics   Rhythmic G.
# 29007  Beijing     2008      Tennis        Tennis
#
#                               Athlete  NOC Gender                 Event  \
# 7                    ANDREOU, Joannis  GRE    Men       1200m freestyle
# 82           ANDRIAKOPOULOS, Nicolaos  GRE    Men         rope climbing
# 110          ANDRIAKOPOULOS, Nicolaos  GRE    Men   team, parallel bars
# ...

# %%
pd1[pd1['Gender']=='Women'].sort_values(by='Edition')

#My Code to See in Which Year First Women Appeared
# Out:
#           City  Edition       Sport       Discipline            Athlete  NOC  \
# 416      Paris     1900        Golf             Golf       PRATT, Daria  USA
# 650      Paris     1900      Tennis           Tennis    PREVOST, Hélène  FRA
# 649      Paris     1900      Tennis           Tennis  COOPER, Charlotte  GBR
# 647      Paris     1900      Tennis           Tennis      JONES, Marion  USA
# 642      Paris     1900      Tennis           Tennis    PREVOST, Hélène  ZZX
# ...        ...      ...         ...              ...                ...  ...
# 27868  Beijing     2008  Basketball       Basketball  CATCHINGS, Tamika  USA
# 27869  Beijing     2008  Basketball       Basketball     FOWLES, Sylvia  USA
# 27870  Beijing     2008  Basketball       Basketball       LAWSON, Kara  USA
# 27858  Beijing     2008  Basketball       Basketball     KUZINA, Marina  RUS
# 29172  Beijing     2008   Wrestling  Wrestling Free.    ZLATEVA, Stanka  BUL
#
# ...

# %%
# Out:
#          Edition
# Gender
# Men     42601544
# Women   14887164
