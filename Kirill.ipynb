# %%
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
male=np.random.normal(175.5,7.4,1000)
female=np.random.normal(161.8,6.9,1000)

# %%
sns.distplot(male,kde=False)

# %%
sns.kdeplot(male)

# %%
sns.distplot(female,kde=False)

# %%
sns.kdeplot(female)
